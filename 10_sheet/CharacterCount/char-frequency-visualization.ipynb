# %%
from collections import OrderedDict
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# Output of the hadoop job has the following format:

# %%
# !head part-r-00000
# Out:
# !	1575
# "	1
# #	2
# $	2
# %	6
# &	4
# '	1
# (	1796
# )	1808
# *	28

# %% [markdown]
# Parse file:

# %%
char_occurences = {}
sum_count = 0
with open('part-r-00000') as f:
    for line in f:
        char, count = line.split()
        count = int(count)
        char_occurences[char] = count
        sum_count += count

# %% [markdown]
# Divide absolute frequencies by total amount of chars to get relative frequency in text:

# %%
for key, val in char_occurences.items():
    char_occurences[key] /= sum_count

# %% [markdown]
# Sort by declining frequency:

# %%
sorted_occurences = sorted(char_occurences.items(), key=lambda x: -x[1])

# %%
plt.figure(figsize=(20,8), dpi=120)
chars, occurences = list(zip(*sorted_occurences))
plt.title('Characters and their relative frequency in ulysses.txt')
plt.xlabel('Characters')
plt.ylabel('Relative frequency')
plt.bar(chars, occurences);

# %% [markdown]
# Relative frequencies of characters. (taken from https://en.wikipedia.org/wiki/Letter_frequency#Relative_frequencies_of_letters_in_the_English_language)
#
# The frequencies that are outputted when analyzing the `ulysses.txt` file resemble the following one:
# ![](letter-freq-plot.png)
