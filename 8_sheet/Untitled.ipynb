# %%
# !ls
# Out:
# 2-a.c	2-c.cu	   3-serial.cpp  cuda.csvdata	 serial.out
# 2-b.cu	3-cuda.cu  a.out	 serial.csvdata  Untitled.ipynb

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df_cuda = pd.read_csv('cuda.csvdata', sep=';', header=None)
df_serial = pd.read_csv('serial.csvdata', sep=';', header=None)

# %%
plt.figure(dpi=160, figsize=(5,5));
plt.imshow(df_cuda);
plt.colorbar();

# %%
plt.figure(dpi=160, figsize=(5,5));
plt.imshow(df_serial);
plt.colorbar();
