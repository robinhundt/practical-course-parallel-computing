# %%
# !ls
# Out:
# 2-a.c	3-cuda.cu     cuda-32.csv   serial-32.csv   serial.out
# 2-b.cu	3-serial.cpp  cuda.csv	    serial.csv	    Untitled.ipynb
# 2-c.cu	a.out	      cuda.csvdata  serial.csvdata

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df_cuda = pd.read_csv('cuda.csv', sep=';', header=None)
df_serial = pd.read_csv('serial.csv', sep=';', header=None)

# %% [markdown]
# ### The figures show the matrix after the initializaton in the upper part and aftere the iteration in the lower part.

# %%
plt.figure(dpi=320, figsize=(14,14));
plt.title("Cuda version")
plt.imshow(df_cuda);
plt.colorbar();

# %%
plt.figure(dpi=320, figsize=(14,14));
plt.title("Serial version")
plt.imshow(df_serial);
plt.colorbar();

# %%
df_cuda = pd.read_csv('cuda-32.csv', sep=';', header=None)
df_serial = pd.read_csv('serial-32.csv', sep=';', header=None)

# %%
plt.figure(dpi=160, figsize=(5,5));
plt.imshow(df_cuda);
plt.colorbar();

# %%
plt.figure(dpi=160, figsize=(5,5));
plt.imshow(df_serial);
plt.colorbar();

# %% [markdown]
# ### Evidently the initialization step is working on the cuda version, the jacobi iteration however is not.
